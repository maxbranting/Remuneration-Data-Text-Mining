# %% [markdown]
# # Analysis of .............

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# merge of original data and mined data
df = pd.read_excel('C:\Users\maxim\Desktop\Business Projects_Hryckiewicz_FinancialCompensation.xlsx')
# Out:
#   Input In [5]
#     df = pd.read_excel('C:\Users\maxim\Desktop\Business Projects_Hryckiewicz_FinancialCompensation.xlsx')
#                                                                                                         ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %% [markdown]
# ## Plotting and so on.......
