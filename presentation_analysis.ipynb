# %% [markdown]
# # Analysis of .............

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# merge of original data and mined data
df = pd.read_csv(r"C:\Users\maxim\Desktop\original_data_2.csv", delimiter=';')
# Out:
# Traceback (most recent call last):
#
#   File c:\Users\maxim\Documents\GitHub\Remuneration-Data-Text-Mining\textmining\lib\site-packages\IPython\core\interactiveshell.py:3398 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Input In [2] in <cell line: 2>
#     df = pd.read_excel(r"C:\Users\maxim\Desktop\original_data.xlsx", sheet_name=['Sheet1'])
#
#   File c:\Users\maxim\Documents\GitHub\Remuneration-Data-Text-Mining\textmining\lib\site-packages\pandas\util\_decorators.py:311 in wrapper
#     return func(*args, **kwargs)
#
#   File c:\Users\maxim\Documents\GitHub\Remuneration-Data-Text-Mining\textmining\lib\site-packages\pandas\io\excel\_base.py:457 in read_excel
#     io = ExcelFile(io, storage_options=storage_options, engine=engine)
#
#   File c:\Users\maxim\Documents\GitHub\Remuneration-Data-Text-Mining\textmining\lib\site-packages\pandas\io\excel\_base.py:1363 in __init__
#     if import_optional_dependency("xlrd", errors="ignore") is None:
#
# ...

# %% [markdown]
# ## Plotting and so on.......
