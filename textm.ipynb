# %% [markdown]
# ## TEXT MINING PROJECT <font color=green> **In progress**</font>
# ***
#
# The goal of this project is to fill in missing data in another dataset. Originally it was downloaded from Bloomberg and concerned the compensation of higher managament for various banks around the world. Data from bloomberg was found to be missing a lot of entries so it was decided to fill in the missing information by getting bank reports from the web and extracting it from them. End result of this project should be a dataframe that could be joined with existing one.
#
# Below are five main steps of this work:
# 1. Basic preparation.
# 2. Defining specific keywords.
# 3. Identifying which pages of the pdf's contain right information.
# 4. Extracting the data from beforementioned pages and filling NA's in original dataset.
# 5. Creating a dataframe from the extracted data.
# ***

# %% [markdown]
# ### 1. Preparation
# * ##### Importing

# %%
import sys, os
import PyPDF2
import re
import pandas as pd
import pikepdf
import tabula
import tabula.io
from tabula.io import read_pdf

# %% [markdown]
# * ##### Listing all PDF files
# Firstly a list of pdfs needs to be created. For that we fetch directory of all pdfs which later is used in a loop to append the list with file report names.

# %%
paths = [r'C:\Users\maxim\Documents\GitHub\text-mining\Reports', r'C:\Users\mi.martowicz\Documents\GitHub\text-mining\Reports']

for i in paths:                                                     #choosing correct path
    if os.path.isdir(i) == True:
        pth = i
    else:
        continue 

pdf_dir = os.listdir(pth)                                           #taking pdf names out of path of every file

pdf_list = []

for file in pdf_dir:
    pdf_list.append(file)                                           #creating list of pdf names

for n in pdf_list:
    pdf = pikepdf.open(pth + '/' + n, allow_overwriting_input=True)       #decripting pdf's
    pdf.save(pth + '/' + n)

# %% [markdown]
#  ***
#  ### 2. Keywords
# Here are gathered all keywords that will be used for finding the pages of interest as well as for extraction later on.

# %%
key_words = {'exec': ['ceo', 'chief executive', 'chief executive officer', 'director'], 
    'pay': ['commission', 'remuneration', 'salary', 'compensation', 'benefits', 'variable remuneration', 
    'fixed remuneration', 'clawback', 'emoluments', 'exceptional remuneration', 'fixed fees', 'attendance fees']}

# %% [markdown]
#  ***
#  ### 3. Building first loop
# The goal for now is to create a directory of lists that will have title of the report and page numbers which contain the information of our interest.<br>
# Page numbers are appended only if the page intersects with one word from keywords regarding remuneration and executive titles

# %% [markdown]
# * ##### Definig variables needed for the loop

# %%
test_pdf = [pdf_list[7], pdf_list[15], pdf_list[18]]         # for testing we will do just two pdf's so im defining new list with two file titles
pdf_pages = {}                                  # empty dictionary , it will store the title of pdf and pages where it found matching keywords
word_set_1 = set(key_words['exec'])
word_set_2 = set(key_words['pay'])              # word sets for intersecting text later in the loop

# %% [markdown]
# * ##### Loop

# %%
for element in pdf_list:
    document = PyPDF2.PdfFileReader(pth + '/' + element, strict=False)
    no_pages = document.getNumPages()                               # here we retrieve number of pages to enable us to iterate through them below
    pagenum_list=[]                                                 # defining list for page numbers     
    for i in range(no_pages):
        text = document.getPage(i).extractText().lower()                                    # extracting text from a page and florring the letters
        text_set = set(text.split())                                                        # set and split allows us to later iterate throug words
        if word_set_1.intersection(text_set) and word_set_2.intersection(text_set):
            pagenum_list.append(i)                                                          # appending list with page numbers
    pdf_pages[element] = pagenum_list                                                       # appending dictionary of lists
# Out:
# ...
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\maxim\Documents\GitHub\text-mining\textm.ipynb Cell 12' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/maxim/Documents/GitHub/text-mining/textm.ipynb#ch0000011?line=3'>4</a> pagenum_list=[]                                                 # defining list for page numbers
#       <a href='vscode-notebook-cell:/c%3A/Users/maxim/Documents/GitHub/text-mining/textm.ipynb#ch0000011?line=4'>5</a> for i in range(no_pages):
# ----> <a href='vscode-notebook-cell:/c%3A/Users/maxim/Documents/GitHub/text-mining/textm.ipynb#ch0000011?line=5'>6</a>     text = document.getPage(i).extractText().lower()                                    # extracting text from a page and florring the letters
# ...

# %% [markdown]
# * ##### Test
# And a quick test to see if it works, here we chose Santander because it only found one page.
# From the results we can quickly see that it worked perfectly. in the pdf this page is a table with remuneration
# in thousands of EUR

# %%
print(pdf_pages)
# Out:
# {'EUROBANK2009.pdf': [12], 'EUROBANK2012.pdf': [20], 'EUROBANK2013.pdf': [18], 'EUROBANK2014.pdf': [20, 23], 'EUROBANK2015.pdf': [], 'EUROBANK2016.pdf': [23, 24, 29, 34], 'EUROBANK2017.pdf': [], 'Grupo Cooperativo Cajamar 2010.pdf': [238], 'Grupo Cooperativo Cajamar 2011.pdf': [211, 257, 258, 259, 265], 'Grupo Cooperativo Cajamar 2012.pdf': [], 'Grupo Cooperativo Cajamar 2013.pdf': [], 'Grupo Cooperativo Cajamar 2014.pdf': [], 'HSBC 2009.pdf': [], 'HSBC 2010.pdf': [], 'HSBC 2011.pdf': [5, 28, 29, 30, 33, 34, 40, 43, 44, 45, 47, 48], 'HSBC 2012.pdf': [9, 11, 32, 33, 34, 37, 40, 41, 44, 45, 47, 49, 50, 51, 52, 53, 54, 55, 61], 'HSBC 2013.pdf': [1, 5, 6, 45, 47, 333, 334, 335, 336, 342, 344, 346, 350, 354, 361, 363, 372, 376, 381, 382, 386, 387, 388, 389, 390, 391, 392, 393, 394, 397, 399, 401, 402, 403, 407, 409, 466], 'HSBC 2014.pdf': [7, 118, 279, 281, 285, 286, 298, 301, 303, 308, 312, 313, 319, 320, 321, 325, 334], 'SANTANDER CONSUMER FINANCE SPAIN 2010.pdf': [58], 'SANTANDER CONSU
# ...

# %%
test = PyPDF2.PdfFileReader(pth + '/' + pdf_list[18], strict=False)
text123 = test.getPage(58).extractText()
print(text123)
# Out:
#
# 51
#
# The detail, by director, of the aforementioned remune
# ration is as follows:
#
# Thousands of Euros
#  2010 2009
#
# Bylaw-
#
#
# Bylaw-
#
#
#  Stipulated
#
# Attendance
#
#  Stipulated
#
# Attendance
#
#
# Directors Emoluments
#
# Fees Total Emoluments
#
# Fees Total
#
#
# Mr. Antonio Escámez Torres
# -
#
# -
#
# -
#
# - - -
# Mr. Javier San Félix García
# -
#
# -
#
# -
#
# - - -
# Ms. Magdalena Salarich
# -
#
# -
#
# -
#
# - - -
# Mr. David Turiel López
# -
#
# -
#
# -
#
# - - -
# Ms. Inés Serrano González
# -
#
# -
#
# -
#
# - - -
# Mr. Ernesto Zulueta Benito - - - - - -
# Mr. José Antonio Álvarez Álvarez - - - - - -
# Mr. José María Espí Martínez - - - - - -
# Mr. Juan Rodríguez Inciarte - - - - - -
# Mr. Luis Valero Artola (*)
#
# 50 1 51 25 11 36
# Mr. Paul Adrian Verburgt (*) 25 1 26 25 7 32
#
# 75 2 77 50 18 68
# (*) Director who was a Board member for some months
#  in 2010 but ceased to be a director prior to 31 De
# cember 2010.
# ...

# %% [markdown]
# ***
# ### 4. Extracting desirable data

# %% [markdown]
# * ##### New keyword dictionary <br>
# We need to differientiate between keywords regarding fixed remmuneration and additional bonuses.

# %%
keywords_pay = {'fixed': ['remuneration', 'salary', 'compensation', 'fixed remuneration', 'emoluments', 'fixed fees', 'attendance fees'], 
    'variable': ['benefits', 'variable remuneration', 'exceptional remuneration', 'clawback', 'commission', 'variable fees', 
    'variable remuneration', 'variable compensation', 'variable fees']}

# %% [markdown]
# * ##### Defining variables needed for the loop

# %%
#pdf_pages
#path = r'C:\Users\maxim\Documents\GitHub\text-mining\Reports/'
word_set_fix = set(keywords_pay['fixed'])
word_set_var = set(keywords_pay['variable'])

#test doc for loop
loop2_test = {'HSBC 2012.pdf': pdf_pages['HSBC 2012.pdf']}

# %% [markdown]
# * ##### Loop
#
# <font color=red> We may have to ditch PyPDF2, it did its thing well before <br>
# but as seen below it onyl extracts singular words with different solutions <br>
# it may turn out that the first loop isnt needed </font>
#
# <font color=blue> **Update** </font> <br> I found a method for extracting tables from pdfs, we could try first running through all pdfs <br>
# and then if a table is found and it has kw's from pay the name of the file is deleted from list, <br>
# rest of the list will go through a loop similar to one below where the words are tokenized. <br>
# Also if we do the table option then we **have to keep** the first loop from this notebook

# %% [markdown]
# **Method for extracting tables**
#
# problems... again :) <br> UnicodeDecodeError: 'utf-8' codec can't decode byte 0xbd in position 965: invalid start byte <br>
# we may have to find a way to read of the encoding of each file or read them in as images and use yet again different method of extraction

# %%
for title, pages in loop2_test.items():
    tables = tabula.read_pdf(pth + '/' + title, pages = pages, encoding = 'UTF-8')

tables
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# c:\Users\maxim\Documents\GitHub\text-mining\textm.ipynb Cell 24' in <cell line: 1>()
#       <a href='vscode-notebook-cell:/c%3A/Users/maxim/Documents/GitHub/text-mining/textm.ipynb#ch0000023?line=0'>1</a> for title, pages in loop2_test.items():
# ----> <a href='vscode-notebook-cell:/c%3A/Users/maxim/Documents/GitHub/text-mining/textm.ipynb#ch0000023?line=1'>2</a>     tables = tabula.read_pdf(pth + '/' + title, pages = pages, encoding = 'UTF-8')
#       <a href='vscode-notebook-cell:/c%3A/Users/maxim/Documents/GitHub/text-mining/textm.ipynb#ch0000023?line=3'>4</a> tables
#
# File c:\Users\maxim\AppData\Local\Programs\Python\Python310\lib\site-packages\tabula\io.py:322, in read_pdf(input_path, output_format, encoding, java_options, pandas_options, multiple_tables, user_agent, **kwargs)
# ...

# %%
for title, pages in loop2_test.items():
    doc = PyPDF2.PdfFileReader(pth + '/' + title, strict=False)
    page_nums = pages
    var_page = []
    fix_page = []
    for page in page_nums:
        content = doc.getPage(page).extractText().lower()
        content_set = text.split()                              # we are not using "set" because it scrambles the order of words
        if word_set_fix.intersection(content_set):
            # maybe append to somewhere?
        elif word_set_var.intersection(content_set):
            # same as above

    #maybe we should do something that will take x amount of "words" after the keyword
    #and then extract all digits in the original order if there are any

# %% [markdown]
# ##### Like here the text is much better but still not the best notice the rows around 4.95k< mark where <br> remun info appears, number are all in one column together with years, it may become a problem later on

# %%
#import fitz
#import nltk.tokenize
#for
#with fitz.open(path + 'HSBC 2012.pdf') as doc:
#    text = ""
#    for page in doc:
#        text += page.get_text()

#text2= str(text)

#token = word_tokenize(text2)
#print(text2)

# %% [markdown]
# ***
# ### 5. Creating the dataframe
